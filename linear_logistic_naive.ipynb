# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

df = pd.read_csv('/content/sample_data/music.csv')

x = df.drop(columns=['genre'])
y = df['genre']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#Linear Regression
# encoder = LabelEncoder()
# y = encoder.fit_transform(df['genre'])

# lin_model = LinearRegression()
# lin_model.fit(x_train, y_train)

# raw_pred = lin_model.predict(x_test)
# rounded_pred = raw_pred.round().astype(int)

# final_pred_genres = encoder.inverse_transform(np.clip(rounded_pred, 0, len(encoder.classes_)-1))
# print("Linear Regression (Đã mã hóa số) Accuracy:", accuracy_score(y_test, rounded_pred))

#Logistic Regression
# log_model = LogisticRegression()
# log_model.fit(x_train, y_train)

# prediction = log_model.predict(x_test)
# print('Do chinh xac: ', accuracy_score(y_test, prediction))

# print('Du doan: ', log_model.predict([[21, 1]]))

#Naive Bayes
# nai_model = GaussianNB()
# nai_model.fit(x_train, y_train)

# prediction = nai_model.predict(x_test)
# print('Do chinh xac: ', accuracy_score(y_test, prediction))

# new_user = [[21, 1]]
# print("Dự đoán nhạc thích hợp:", nai_model.predict(new_user))
# Out:
# Do chinh xac:  0.5
# Dự đoán nhạc thích hợp: ['Jazz']
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
